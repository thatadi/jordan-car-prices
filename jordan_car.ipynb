# %% [markdown]
# <a href="https://colab.research.google.com/github/thatadi/jordan-car-prices/blob/main/jordan_car.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('car_prices_jordan.csv')
df
# Out:
#      Unnamed: 0                        Model                   Property  \
# 0             0                  Byd F0 2018                     Manual
# 1             1             Suzuki Alto 2023                     manual
# 2             2          Suzuki Celerio 2019                  Automatic
# 3             3          Changan E Star 2023                  Automatic
# 4             4       Hyundai Grand i10 2020                  Automatic
# ..          ...                          ...                        ...
# 361         361  Land Rover Range Rover 2023            Automatic / HSE
# 362         362   Maserati Quattroporte 2022  Automatic / GTS GranLusso
# 363         363        Maserati Levante 2022         Automatic / Trofeo
# 364         364            Genesis GV80 2022       Automatic / Prestige
# 365         365      Cadillac Ecalade V 2023                     manual
#
#               Power    Price
# 0           1000 CC    6,900
# 1            800 CC    8,250
# ...

# %%
df['Price'] = df['Price'].str.replace(',', '').astype(float)

# %%
df.describe()
# Out:
#        Unnamed: 0          Price
# count  366.000000     366.000000
# mean   182.500000   52647.519126
# std    105.799338   40645.971748
# min      0.000000    6900.000000
# 25%     91.250000   25000.000000
# 50%    182.500000   39000.000000
# 75%    273.750000   69000.000000
# max    365.000000  250000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  366 non-null    int64
#  1   Model       366 non-null    object
#  2   Property    366 non-null    object
#  3   Power       366 non-null    object
#  4   Price       366 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 14.4+ KB

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
X=df.drop('Price', axis=1)
x=pd.get_dummies(X)
y=df['Price']

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(train_x)
X_test = scaler.transform(test_x)

# %%
model= Sequential()
model.add(Dense(units = 20, activation = 'relu',input_shape=(train_x.shape[1],)))
model.add(Dense(units = 10, activation = 'relu'))
model.add(Dense(units = 4, activation = 'relu'))
model.add(Dense(units = 1,activation='linear'))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
model.fit(train_x, train_y, batch_size=1,  epochs = 100)
# Out:
# Epoch 1/100
# 256/256 [==============================] - 1s 2ms/step - loss: 3889097984.0000 - mae: 50647.7852
# Epoch 2/100
# 256/256 [==============================] - 0s 1ms/step - loss: 3885730048.0000 - mae: 50613.3789
# Epoch 3/100
# 256/256 [==============================] - 0s 2ms/step - loss: 3859958784.0000 - mae: 50347.6172
# Epoch 4/100
# 256/256 [==============================] - 0s 2ms/step - loss: 3773986816.0000 - mae: 49469.3945
# Epoch 5/100
# 256/256 [==============================] - 0s 2ms/step - loss: 3588866816.0000 - mae: 47506.2031
# Epoch 6/100
# 256/256 [==============================] - 0s 2ms/step - loss: 3286851584.0000 - mae: 44097.8242
# Epoch 7/100
# 256/256 [==============================] - 0s 1ms/step - loss: 2894536960.0000 - mae: 39214.0117
# Epoch 8/100
# 256/256 [==============================] - 0s 1ms/step - loss: 2470727168.0000 - mae: 33982.8203
# Epoch 9/100
# ...

# %%
pred_y=model.predict(test_x)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
print("R2_Score : " ,r2_score(test_y,pred_y))
print("Mean Squared Error : ", mean_squared_error(test_y,pred_y))
print("Root Mean Squared Error : ", np.sqrt(mean_squared_error(test_y,pred_y)))
# Out:
# R2_Score :  0.6361278651186207
# Mean Squared Error :  862349267.7700578
# Root Mean Squared Error :  29365.78396314421
